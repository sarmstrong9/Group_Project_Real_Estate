# %%
import pandas as pd
pd.set_option('display.max_columns', None)
raw_housing_df = pd.read_csv('weekly_housing_market_data_most_recent.tsv', sep='\t', header=0)
# Out:
#    region_id  region_type_id            region_name region_type period_begin  \
# 0        913               5       Boone County, IA      county   2018-11-19
# 1       3036               5    Charlottesville, VA      county   2018-09-03
# 2      45780              -2  Toledo, OH metro area       metro   2017-02-06
# 3       1885               5     Grafton County, NH      county   2019-05-27
# 4        819               5       Boone County, IN      county   2017-03-06
#
#    period_end duration  total_homes_sold  total_homes_sold_yoy  \
# 0  2018-11-25  1 weeks               1.0             -0.500000
# 1  2018-09-09  1 weeks               7.0              0.166667
# 2  2017-02-12  1 weeks             100.0              0.075269
# 3  2019-06-02  1 weeks              43.0             -0.085106
# 4  2017-03-12  1 weeks              18.0              0.200000
#
#    average_homes_sold  average_homes_sold_yoy  \
# 0                 1.0               -0.500000
# ...

# %%
raw_housing_df
# Out:
#          region_id  region_type_id            region_name region_type  \
# 0              913               5       Boone County, IA      county
# 1             3036               5    Charlottesville, VA      county
# 2            45780              -2  Toledo, OH metro area       metro
# 3             1885               5     Grafton County, NH      county
# 4              819               5       Boone County, IN      county
# ...            ...             ...                    ...         ...
# 2397901       1692               5   St. Clair County, MO      county
# 2397902       1692               5   St. Clair County, MO      county
# 2397903       1628               5        Dade County, MO      county
# 2397904       2868               5       Tyler County, TX      county
# 2397905       1628               5        Dade County, MO      county
#
#         period_begin  period_end duration  total_homes_sold  \
# 0         2018-11-19  2018-11-25  1 weeks               1.0
# ...

# %%
raw_housing_df["state"] = raw_housing_df["region_name"].str[-2:]
raw_housing_df["state"]
# Out:
# 0          IA
# 1          VA
# 2          ea
# 3          NH
# 4          IN
#            ..
# 2397901    MO
# 2397902    MO
# 2397903    MO
# 2397904    TX
# 2397905    MO
# Name: state, Length: 2397906, dtype: object

# %%
raw_housing_df["state"].value_counts()
# Out:
# ea    596703
# TX    160665
# GA    124945
# VA     98088
# NC     78279
# IN     75941
# TN     74364
# OH     73926
# MN     73092
# IL     72858
# MO     69202
# AR     61068
# WI     60552
# MS     57891
# OK     52211
# FL     50350
# KY     48547
# CA     44861
# NY     39527
# MI     38686
# SC     38304
# CO     33527
# LA     32663
# WA     28594
# PA     28539
# OR     28424
# ID     26628
# UT     22689
# AL     20442
# MD     20184
# NJ     17661
# IA     16820
# ME     13456
# NV     13337
# NE     12939
# VT     11774
# MA     11774
# NM      9614
# KS      9251
# NH      8410
# AZ      8321
# CT      6728
# WV      5887
# RI      4205
# SD      4205
# AK      4205
# HI      3364
# DE      2523
# os       841
# DC       841
# Name: state, dtype: int64

# %%
raw_housing_df["year"] = raw_housing_df["period_end"].str[:4]
raw_housing_df["year"]
# Out:
# 0          2018
# 1          2018
# 2          2017
# 3          2019
# 4          2017
#            ...
# 2397901    2020
# 2397902    2017
# 2397903    2020
# 2397904    2020
# 2397905    2019
# Name: year, Length: 2397906, dtype: object

# %%
raw_housing_df["year"].value_counts()
# Out:
# 2021    457814
# 2020    448811
# 2019    443509
# 2018    435592
# 2017    387748
# 2022    224432
# Name: year, dtype: int64

# %%
raw_housing_df
# Out:
#          region_id  region_type_id            region_name region_type  \
# 0              913               5       Boone County, IA      county
# 1             3036               5    Charlottesville, VA      county
# 2            45780              -2  Toledo, OH metro area       metro
# 3             1885               5     Grafton County, NH      county
# 4              819               5       Boone County, IN      county
# ...            ...             ...                    ...         ...
# 2397901       1692               5   St. Clair County, MO      county
# 2397902       1692               5   St. Clair County, MO      county
# 2397903       1628               5        Dade County, MO      county
# 2397904       2868               5       Tyler County, TX      county
# 2397905       1628               5        Dade County, MO      county
#
#         period_begin  period_end duration  total_homes_sold  \
# 0         2018-11-19  2018-11-25  1 weeks               1.0
# ...

# %%
yearly_housing_data_df = raw_housing_df.groupby(raw_housing_df["year"])
yearly_housing_data_df.head()
# Out:
#      region_id  region_type_id                       region_name region_type  \
# 0          913               5                  Boone County, IA      county
# 1         3036               5               Charlottesville, VA      county
# 2        45780              -2             Toledo, OH metro area       metro
# 3         1885               5                Grafton County, NH      county
# 4          819               5                  Boone County, IN      county
# 5          680               5                  Camas County, ID      county
# 6        13380              -2         Bellingham, WA metro area       metro
# 7          680               5                  Camas County, ID      county
# 8        45780              -2             Toledo, OH metro area       metro
# 9        32300              -2       Martinsville, VA metro area       metro
# 10       32300              -2       Martinsville, VA metro area       metro
# ...
