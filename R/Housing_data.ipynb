# %%
import pandas as pd
pd.set_option('display.max_columns', None)
raw_housing_df = pd.read_csv('state_market_tracker.tsv000', sep='\t', header=0)

# %%
raw_housing_df
# Out:
#       period_begin  period_end  period_duration region_type  region_type_id  \
# 0       2020-11-01  2020-11-30               30       state               4
# 1       2019-07-01  2019-07-31               30       state               4
# 2       2016-11-01  2016-11-30               30       state               4
# 3       2013-02-01  2013-02-28               30       state               4
# 4       2020-02-01  2020-02-29               30       state               4
# ...            ...         ...              ...         ...             ...
# 28970   2021-10-01  2021-10-31               30       state               4
# 28971   2015-08-01  2015-08-31               30       state               4
# 28972   2013-11-01  2013-11-30               30       state               4
# 28973   2016-12-01  2016-12-31               30       state               4
# 28974   2016-12-01  2016-12-31               30       state               4
#
# ...

# %%
raw_housing_df.columns
# Out:
# Index(['period_begin', 'period_end', 'period_duration', 'region_type',
#        'region_type_id', 'table_id', 'is_seasonally_adjusted', 'region',
#        'city', 'state', 'state_code', 'property_type', 'property_type_id',
#        'median_sale_price', 'median_sale_price_mom', 'median_sale_price_yoy',
#        'median_list_price', 'median_list_price_mom', 'median_list_price_yoy',
#        'median_ppsf', 'median_ppsf_mom', 'median_ppsf_yoy', 'median_list_ppsf',
#        'median_list_ppsf_mom', 'median_list_ppsf_yoy', 'homes_sold',
#        'homes_sold_mom', 'homes_sold_yoy', 'pending_sales',
#        'pending_sales_mom', 'pending_sales_yoy', 'new_listings',
#        'new_listings_mom', 'new_listings_yoy', 'inventory', 'inventory_mom',
#        'inventory_yoy', 'months_of_supply', 'months_of_supply_mom',
#        'months_of_supply_yoy', 'median_dom', 'median_dom_mom',
#        'median_dom_yoy', 'avg_sale_to_list', 'avg_sale_to_list_mom',
# ...

# %%
cleaned_housing_df = raw_housing_df.drop(['region_type_id','table_id', 'city','property_type_id','median_sale_price_mom','median_sale_price_yoy','median_list_price_mom'  ], axis=1)

# %%
cleaned_housing_df.head()
# Out:
#   period_begin  period_end  period_duration region_type  \
# 0   2020-11-01  2020-11-30               30       state
# 1   2019-07-01  2019-07-31               30       state
# 2   2016-11-01  2016-11-30               30       state
# 3   2013-02-01  2013-02-28               30       state
# 4   2020-02-01  2020-02-29               30       state
#
#   is_seasonally_adjusted       region        state state_code  \
# 0                      f     Illinois     Illinois         IL
# 1                      f  Connecticut  Connecticut         CT
# 2                      f     Illinois     Illinois         IL
# 3                      f       Kansas       Kansas         KS
# 4                      f     Virginia     Virginia         VA
#
#                property_type  median_sale_price  median_list_price  \
# 0            All Residential             240700           237800.0
# 1  Single Family Residential             310900           267700.0
# ...

# %%
cleaned_housing_df.columns
# Out:
# Index(['period_begin', 'period_end', 'period_duration', 'region_type',
#        'is_seasonally_adjusted', 'region', 'state', 'state_code',
#        'property_type', 'median_sale_price', 'median_list_price',
#        'median_list_price_yoy', 'median_ppsf', 'median_ppsf_mom',
#        'median_ppsf_yoy', 'median_list_ppsf', 'median_list_ppsf_mom',
#        'median_list_ppsf_yoy', 'homes_sold', 'homes_sold_mom',
#        'homes_sold_yoy', 'pending_sales', 'pending_sales_mom',
#        'pending_sales_yoy', 'new_listings', 'new_listings_mom',
#        'new_listings_yoy', 'inventory', 'inventory_mom', 'inventory_yoy',
#        'months_of_supply', 'months_of_supply_mom', 'months_of_supply_yoy',
#        'median_dom', 'median_dom_mom', 'median_dom_yoy', 'avg_sale_to_list',
#        'avg_sale_to_list_mom', 'avg_sale_to_list_yoy', 'sold_above_list',
#        'sold_above_list_mom', 'sold_above_list_yoy', 'price_drops',
#        'price_drops_mom', 'price_drops_yoy', 'off_market_in_two_weeks',
# ...

# %%
cleaned_housing_df= cleaned_housing_df.drop(['median_list_price_yoy','median_ppsf','median_ppsf_mom','median_ppsf_yoy','median_list_ppsf','median_list_ppsf_mom','median_list_ppsf_yoy','homes_sold_mom','homes_sold_yoy'], axis=1)

# %%
cleaned_housing_df.head()
# Out:
#   period_begin  period_end  period_duration region_type  \
# 0   2020-11-01  2020-11-30               30       state
# 1   2019-07-01  2019-07-31               30       state
# 2   2016-11-01  2016-11-30               30       state
# 3   2013-02-01  2013-02-28               30       state
# 4   2020-02-01  2020-02-29               30       state
#
#   is_seasonally_adjusted       region        state state_code  \
# 0                      f     Illinois     Illinois         IL
# 1                      f  Connecticut  Connecticut         CT
# 2                      f     Illinois     Illinois         IL
# 3                      f       Kansas       Kansas         KS
# 4                      f     Virginia     Virginia         VA
#
#                property_type  median_sale_price  median_list_price  \
# 0            All Residential             240700           237800.0
# 1  Single Family Residential             310900           267700.0
# ...

# %%
cleaned_housing_df.columns
# Out:
# Index(['period_begin', 'period_end', 'period_duration', 'region_type',
#        'is_seasonally_adjusted', 'region', 'state', 'state_code',
#        'property_type', 'median_sale_price', 'median_list_price', 'homes_sold',
#        'pending_sales', 'pending_sales_mom', 'pending_sales_yoy',
#        'new_listings', 'new_listings_mom', 'new_listings_yoy', 'inventory',
#        'inventory_mom', 'inventory_yoy', 'months_of_supply',
#        'months_of_supply_mom', 'months_of_supply_yoy', 'median_dom',
#        'median_dom_mom', 'median_dom_yoy', 'avg_sale_to_list',
#        'avg_sale_to_list_mom', 'avg_sale_to_list_yoy', 'sold_above_list',
#        'sold_above_list_mom', 'sold_above_list_yoy', 'price_drops',
#        'price_drops_mom', 'price_drops_yoy', 'off_market_in_two_weeks',
#        'off_market_in_two_weeks_mom', 'off_market_in_two_weeks_yoy',
#        'parent_metro_region', 'parent_metro_region_metro_code',
#        'last_updated'],
#       dtype='object')

# %%
cleaned_housing_df= cleaned_housing_df.drop(['pending_sales_mom','pending_sales_yoy','new_listings_mom','new_listings_yoy','inventory_mom','inventory_yoy','months_of_supply_mom','months_of_supply_yoy','median_dom_mom','median_dom_yoy'], axis=1)

# %%
cleaned_housing_df.head()
# Out:
#   period_begin  period_end  period_duration region_type  \
# 0   2020-11-01  2020-11-30               30       state
# 1   2019-07-01  2019-07-31               30       state
# 2   2016-11-01  2016-11-30               30       state
# 3   2013-02-01  2013-02-28               30       state
# 4   2020-02-01  2020-02-29               30       state
#
#   is_seasonally_adjusted       region        state state_code  \
# 0                      f     Illinois     Illinois         IL
# 1                      f  Connecticut  Connecticut         CT
# 2                      f     Illinois     Illinois         IL
# 3                      f       Kansas       Kansas         KS
# 4                      f     Virginia     Virginia         VA
#
#                property_type  median_sale_price  median_list_price  \
# 0            All Residential             240700           237800.0
# 1  Single Family Residential             310900           267700.0
# ...

# %%
cleaned_housing_df.columns
# Out:
# Index(['period_begin', 'period_end', 'period_duration', 'region_type',
#        'is_seasonally_adjusted', 'region', 'state', 'state_code',
#        'property_type', 'median_sale_price', 'median_list_price', 'homes_sold',
#        'pending_sales', 'new_listings', 'inventory', 'months_of_supply',
#        'median_dom', 'avg_sale_to_list', 'avg_sale_to_list_mom',
#        'avg_sale_to_list_yoy', 'sold_above_list', 'sold_above_list_mom',
#        'sold_above_list_yoy', 'price_drops', 'price_drops_mom',
#        'price_drops_yoy', 'off_market_in_two_weeks',
#        'off_market_in_two_weeks_mom', 'off_market_in_two_weeks_yoy',
#        'parent_metro_region', 'parent_metro_region_metro_code',
#        'last_updated'],
#       dtype='object')

# %%
cleaned_housing_df= cleaned_housing_df.drop(['avg_sale_to_list_mom','avg_sale_to_list_yoy','sold_above_list_mom','sold_above_list_yoy','price_drops_mom','price_drops_yoy','off_market_in_two_weeks_mom','off_market_in_two_weeks_yoy'], axis=1)

# %%
cleaned_housing_df
# Out:
#       period_begin  period_end  period_duration region_type  \
# 0       2020-11-01  2020-11-30               30       state
# 1       2019-07-01  2019-07-31               30       state
# 2       2016-11-01  2016-11-30               30       state
# 3       2013-02-01  2013-02-28               30       state
# 4       2020-02-01  2020-02-29               30       state
# ...            ...         ...              ...         ...
# 28970   2021-10-01  2021-10-31               30       state
# 28971   2015-08-01  2015-08-31               30       state
# 28972   2013-11-01  2013-11-30               30       state
# 28973   2016-12-01  2016-12-31               30       state
# 28974   2016-12-01  2016-12-31               30       state
#
#       is_seasonally_adjusted       region        state state_code  \
# 0                          f     Illinois     Illinois         IL
# 1                          f  Connecticut  Connecticut         CT
# ...

# %%
cleaned_housing_df.columns
# Out:
# Index(['period_begin', 'period_end', 'period_duration', 'region_type',
#        'is_seasonally_adjusted', 'region', 'state', 'state_code',
#        'property_type', 'median_sale_price', 'median_list_price', 'homes_sold',
#        'pending_sales', 'new_listings', 'inventory', 'months_of_supply',
#        'median_dom', 'avg_sale_to_list', 'sold_above_list', 'price_drops',
#        'off_market_in_two_weeks', 'parent_metro_region'],
#       dtype='object')

# %%
cleaned_housing_df= cleaned_housing_df.drop(['parent_metro_region_metro_code','last_updated'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27368\455947947.py in <module>
# ----> 1 final_cleaned_housing_df= cleaned_housing_df.drop(['parent_metro_region_metro_code','last_updated'], axis=1)
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# ...

# %%
final_cleaned_housing_df = cleaned_housing_df

# %%
final_cleaned_housing_df
# Out:
#       period_begin  period_end  period_duration region_type  \
# 0       2020-11-01  2020-11-30               30       state
# 1       2019-07-01  2019-07-31               30       state
# 2       2016-11-01  2016-11-30               30       state
# 3       2013-02-01  2013-02-28               30       state
# 4       2020-02-01  2020-02-29               30       state
# ...            ...         ...              ...         ...
# 28970   2021-10-01  2021-10-31               30       state
# 28971   2015-08-01  2015-08-31               30       state
# 28972   2013-11-01  2013-11-30               30       state
# 28973   2016-12-01  2016-12-31               30       state
# 28974   2016-12-01  2016-12-31               30       state
#
#       is_seasonally_adjusted       region        state state_code  \
# 0                          f     Illinois     Illinois         IL
# 1                          f  Connecticut  Connecticut         CT
# ...

# %%
final_cleaned_housing_df[final_cleaned_housing_df["region"] == "Illinois"]
# Out:
#       period_begin  period_end  period_duration region_type  \
# 0       2020-11-01  2020-11-30               30       state
# 2       2016-11-01  2016-11-30               30       state
# 64      2021-05-01  2021-05-31               30       state
# 71      2016-04-01  2016-04-30               30       state
# 193     2014-05-01  2014-05-31               30       state
# ...            ...         ...              ...         ...
# 28590   2015-07-01  2015-07-31               30       state
# 28741   2013-08-01  2013-08-31               30       state
# 28748   2020-07-01  2020-07-31               30       state
# 28854   2019-03-01  2019-03-31               30       state
# 28855   2019-10-01  2019-10-31               30       state
#
#       is_seasonally_adjusted    region     state state_code  \
# 0                          f  Illinois  Illinois         IL
# 2                          f  Illinois  Illinois         IL
# 64                         f  Illinois  Illinois         IL
# ...

# %%
import datetime as dt
final_cleaned_housing_df['period_begin'] = pd.to_datetime(final_cleaned_housing_df['period_begin']).dt.date

# %%
final_cleaned_housing_df['period_end'] = pd.to_datetime(final_cleaned_housing_df['period_end']).dt.date

# %%
final_cleaned_housing_df
# Out:
#       period_begin  period_end  period_duration region_type  \
# 0       2020-11-01  2020-11-30               30       state
# 1       2019-07-01  2019-07-31               30       state
# 2       2016-11-01  2016-11-30               30       state
# 3       2013-02-01  2013-02-28               30       state
# 4       2020-02-01  2020-02-29               30       state
# ...            ...         ...              ...         ...
# 28970   2021-10-01  2021-10-31               30       state
# 28971   2015-08-01  2015-08-31               30       state
# 28972   2013-11-01  2013-11-30               30       state
# 28973   2016-12-01  2016-12-31               30       state
# 28974   2016-12-01  2016-12-31               30       state
#
#       is_seasonally_adjusted       region        state state_code  \
# 0                          f     Illinois     Illinois         IL
# 1                          f  Connecticut  Connecticut         CT
# ...

# %%
# Import dependencies.
import matplotlib.pyplot as plt
import numpy as np

# %%
x_axis = list(final_cleaned_housing_df["period_begin"])

# %%
x_axis
# Out:
# [datetime.date(2020, 11, 1),
#  datetime.date(2019, 7, 1),
#  datetime.date(2016, 11, 1),
#  datetime.date(2013, 2, 1),
#  datetime.date(2020, 2, 1),
#  datetime.date(2014, 9, 1),
#  datetime.date(2014, 1, 1),
#  datetime.date(2017, 5, 1),
#  datetime.date(2019, 4, 1),
#  datetime.date(2016, 11, 1),
#  datetime.date(2012, 4, 1),
#  datetime.date(2018, 8, 1),
#  datetime.date(2015, 7, 1),
#  datetime.date(2021, 9, 1),
#  datetime.date(2014, 8, 1),
#  datetime.date(2012, 5, 1),
#  datetime.date(2021, 6, 1),
#  datetime.date(2014, 2, 1),
#  datetime.date(2020, 7, 1),
#  datetime.date(2012, 3, 1),
#  datetime.date(2021, 3, 1),
#  datetime.date(2021, 5, 1),
#  datetime.date(2018, 7, 1),
#  datetime.date(2015, 12, 1),
#  datetime.date(2016, 9, 1),
#  datetime.date(2018, 12, 1),
#  datetime.date(2016, 11, 1),
#  datetime.date(2022, 5, 1),
#  datetime.date(2012, 9, 1),
#  datetime.date(2015, 8, 1),
#  datetime.date(2017, 3, 1),
#  datetime.date(2014, 5, 1),
#  datetime.date(2013, 7, 1),
# ...

# %%
price_list=[]
for index,rows in final_cleaned_housing_df.iterrows():
    price = [final_cleaned_housing_df.median_sale_price]
    
    price_list.append(price)

price_list
# Out:
# [[0         240700
#   1         310900
#   2         196800
#   3         147600
#   4         217900
#             ...
#   28970    1591000
#   28971     158200
#   28972     147400
#   28973     312600
#   28974     272700
#   Name: median_sale_price, Length: 28975, dtype: int64],
#  [0         240700
#   1         310900
#   2         196800
#   3         147600
#   4         217900
#             ...
#   28970    1591000
#   28971     158200
#   28972     147400
#   28973     312600
#   28974     272700
#   Name: median_sale_price, Length: 28975, dtype: int64],
#  [0         240700
#   1         310900
#   2         196800
#   3         147600
#   4         217900
#             ...
#   28970    1591000
#   28971     158200
#   28972     147400
#   28973     312600
#   28974     272700
#   Name: median_sale_price, Length: 28975, dtype: int64],
#  [0         240700
#   1         310900
#   2         196800
#   3         147600
#   4         217900
#             ...
# ...

# %%
# Create the plot
plt.plot(x_axis, y_axis)

# %%
plt.scatter(x_axis,y_axis)
